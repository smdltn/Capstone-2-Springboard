# %%
import yfinance as yf
import pandas as pd

# %%
ticker = yf.Ticker('PLTR')
pltr_df = ticker.history(period='max')
pltr_df['Close'].plot(title="Palantir's performance since IPO")

# %%
ticker = yf.Ticker('ASAN')
ASAN_df = ticker.history(period='max')
ASAN_df['Close'].plot(title="ASANA's performance since IPO")

# %%
ticker = yf.Ticker('SNOW')
SNOW_df = ticker.history(period='max')
SNOW_df['Close'].plot(title="Snowflake's performance since IPO")
